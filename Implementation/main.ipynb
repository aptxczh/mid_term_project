# %% [markdown]
# # MTH 9871 Mid-term Project

# %%
"""
Main test file. Generate the result of our code.

Created: 11/27/17

Author: Bingcheng Wang, Yawei Wang & Zhihao Chen
"""
from spread_options import SpreadOption
import numpy as np
import pandas as pd

# %%
## Parameters
r = 0.1
T = 1.0
rho = 0.5
delta_1 = 0.05
sigma_1 = 0.2
delta_2 = 0.05
sigma_2 = 0.1
K = 3

## Test Theorem 1.1

S0 = np.array([10, 5])
N = 1000
eta = 0.1
ep = np.array([-2.1, 0.1])

payoff = SpreadOption(S0, K, T, r).P(N, eta, ep)

print("Exact payoff for spread option: {}".format(max((S0[0] - S0[1] - K), 0)))
print("Calculated payoff for spread option: {}".format(payoff))
# Out:
# 2
# 1.96223632525

# %% [markdown]
# **********************************************************************************

# %%
## Parameters
r = 0.1
T = 1.0
rho = 0.5
delta_1 = 0.05
sigma_1 = 0.2
delta_2 = 0.05
sigma_2 = 0.1

K = np.linspace(0.4, 4, 10)

## Test GBM

S0 = np.array([100, 96])
u_bar = 40
eta = u_bar * 2 / N
ep = np.array([-5.8, 2.8])

s_res1, s_res2, s_res3, s_res4 = [], [], [], []
for k in K:
    s1 = SpreadOption(S0, k, T, r).price(64, eta, ep, "GBM", sigma=np.array([sigma_1, sigma_2]), r=r, T=T, rho=rho)
    s_res1.append(s1)
    s2 = SpreadOption(S0, k, T, r).price(128, eta, ep, "GBM", sigma=np.array([sigma_1, sigma_2]), r=r, T=T, rho=rho)
    s_res2.append(s2)
    s3 = SpreadOption(S0, k, T, r).price(256, eta, ep, "GBM", sigma=np.array([sigma_1, sigma_2]), r=r, T=T, rho=rho)
    s_res3.append(s3)
    s4 = SpreadOption(S0, k, T, r).price(32, eta, ep, "GBM", sigma=np.array([sigma_1, sigma_2]), r=r, T=T, rho=rho)
    s_res4.append(s4)

bm = np.array([8.312461, 8.114994, 7.92082, 7.729932, 7.542324, 7.357984, 7.176902, 6.999065, 6.824458, 6.653065])
res = pd.DataFrame({"Benchmark": bm, "K": K, "64": s_res1, "128": s_res2, "256": s_res3, "32": s_res4})[["Benchmark","K", "32", "64", "128", "256"]]
res
# Out:
#      K         64       128       256       512
# 0  0.4  10.913765  8.331022  8.330968  8.888947
# 1  0.8  10.714267  8.117654  8.117817  8.685345
# 2  1.2  10.436562  7.908524  7.908768  8.485023
# 3  1.6  10.142277  7.703504  7.703793  8.287975
# 4  2.0   9.846346  7.502543  7.502862  8.094194
# 5  2.4   9.553680  7.305605  7.305943  7.903668
# 6  2.8   9.266235  7.112652  7.113003  7.716388
# 7  3.2   8.984872  6.923648  6.924006  7.532340
# 8  3.6   8.709979  6.738555  6.738916  7.351510
# 9  4.0   8.441718  6.557336  6.557695  7.173884

# %%
N = 256
ep = np.array([-5.8, 2.8])
s = SpreadOption(S0, 0.8, T, r).price(N, eta, ep, "GBM", sigma=np.array([sigma_1, sigma_2]), r=r, T=T, rho=rho)
s
# Out:
# 8.1178165468465977

# %% [markdown]
# **********************************************************************************

# %%
## Parameters
r = 0.1
T = 1.0
rho = 0.5
delta_1 = 0.05
sigma_1 = 1.0
rho_1 = -0.5
delta_2 = 0.05
sigma_2 = 0.5
rho_2 = 0.25
v0 = 0.04
kappa = 1.0
mu = 0.04
sigma_v = 0.05

K = np.linspace(2.0, 4.0, 11)

## Test SV
S0 = np.array([100, 96])
u_bar = 40
eta = u_bar * 2 / N
ep = np.array([-25, 20])

s_res1, s_res2, s_res3, s_res4 = [], [], [], []
for k in K:
    s1 = SpreadOption(S0, k, T, r).price(64, eta, ep, "SV", np.array([sigma_1, sigma_2, sigma_v]), r, T, 
                                        np.array([rho, rho_1, rho_2]), kappa, mu, v0, np.array([delta_1, delta_2]))
    s_res1.append(s1)
    s2 = SpreadOption(S0, k, T, r).price(128, eta, ep, "SV", np.array([sigma_1, sigma_2, sigma_v]), r, T, 
                                        np.array([rho, rho_1, rho_2]), kappa, mu, v0, np.array([delta_1, delta_2]))
    s_res2.append(s2)
    s3 = SpreadOption(S0, k, T, r).price(256, eta, ep, "SV", np.array([sigma_1, sigma_2, sigma_v]), r, T, 
                                        np.array([rho, rho_1, rho_2]), kappa, mu, v0, np.array([delta_1, delta_2]))
    s_res3.append(s3)
    s4 = SpreadOption(S0, k, T, r).price(512, eta, ep, "SV", np.array([sigma_1, sigma_2, sigma_v]), r, T, 
                                        np.array([rho, rho_1, rho_2]), kappa, mu, v0, np.array([delta_1, delta_2]))
    s_res4.append(s4)

bm = np.array([8.312461, 8.114994, 7.92082, 7.729932, 7.542324, 7.357984, 7.176902, 6.999065, 6.824458, 6.653065])
res = pd.DataFrame({"Benchmark": bm, "K": K, "64": s_res1, "128": s_res2, "256": s_res3, "32": s_res4})[["Benchmark","K", "32", "64", "128", "256"]]
res
# Out:
#       K      Price
# 0   2.0  17.840056
# 1   2.2  16.481026
# 2   2.4  15.165320
# 3   2.6  13.903242
# 4   2.8  12.700468
# 5   3.0  11.559955
# 6   3.2  10.482959
# 7   3.4   9.469628
# 8   3.6   8.519354
# 9   3.8   7.630995
# 10  4.0   6.803026

# %%
N = 256

for ep1 in range(-20, 0):
    for ep2 in range(1, 20):
        if ep1 + ep2 >= -1:
            continue
        ep = np.array([ep1, ep2])
        s = SpreadOption(S0, 2.2, T, r).price(N, eta, ep, "SV", np.array([sigma_1, sigma_2, sigma_v]), r, T, 
                                        np.array([rho, rho_1, rho_2]), kappa, mu, v0, np.array([delta_1, delta_2]))
        print("{}: {}".format(ep, s))
# Out:
# [-20   1]: -4.714782843889887e+20
# [-20   2]: -888120607197.8403
# [-20   3]: -342727341.2116842
# [-20   4]: 73481339.63743278
# [-20   5]: 1895775.7483218792
# [-20   6]: -369230.77602045186
# [-20   7]: -16323.483654499887
# [-20   8]: 2531.1462107075754
# [-20   9]: 212.67936973305953
# [-20  10]: -23.03021334994018
# [-20  11]: -3.3133189860527725
# [-20  12]: 1.1818504528944738
# [-20  13]: 1.0087473506563653
# [-20  14]: 0.8561077470765395
# [-20  15]: 0.8431408976585338
# [-20  16]: 0.8453714530100125
# [-20  17]: 0.8395372702684291
# [-20  18]: 0.8293125906746451
# [-19   1]: -1.0523573473978094e+19
# [-19   2]: -20054536333.502457
# [-19   3]: 62054788.70108602
# [-19   4]: 3423527.7327468623
# [-19   5]: -306596.18642831297
# [-19   6]: -23618.185098204354
# [-19   7]: 2035.7562162116558
# [-19   8]: 257.54259149931664
# [-19   9]: -17.179870845111754
# [-19  10]: -3.6476840265420387
# [-19  11]: 1.0614761228108882
# [-19  12]: 0.9950914070760223
# [-19  13]: 0.8456215937432563
# [-19  14]: 0.8298530591850443
# [-19  15]: 0.8316621859851151
# [-19  16]: 0.8260886004626932
# [-19  17]: 0.8161337241246863
# [-18   1]: -2.3474603032987872e+17
# [-18   2]: -390028247.58869386
# [-18   3]: 4590954.544154625
# [-18   4]: -213471.40326760226
# [-18   5]: -29086.761666618047
# [-18   6]: 1405.8276370937913
# [-18   7]: 288.8329786960625
# [-18   8]: -10.652053462634617
# [-18   9]: -3.834111315534943
# [-18  10]: 0.9397405746613128
# [-18  11]: 0.9792399897047477
# [-18  12]: 0.8351597401019701
# [-18  13]: 0.8168022434977038
# [-18  14]: 0.8181487549617429
# [-18  15]: 0.812815107593967
# [-18  16]: 0.8031250417251395
# [-17   1]: -5232967561955945.0
# [-17   2]: -4204754.629330765
# [-17   3]: -100329.63815884793
# [-17   4]: -32154.275159045144
# [-17   5]: 690.8469451434923
# [-17   6]: 304.3353846499054
# [-17   7]: -3.7943554803328707
# [-17   8]: -3.8660333059174636
# [-17   9]: 0.8200864118511862
# [-17  10]: 0.9612913705962264
# [-17  11]: 0.8246724600852265
# [-17  12]: 0.8039779094373394
# [-17  13]: 0.8048280235572052
# [-17  14]: 0.7997137562966177
# [-17  15]: 0.790283174062816
# [-16   1]: -116571910519016.06
# [-16   2]: -190910.74048047737
# [-16   3]: -32494.71024091393
# [-16   4]: -49.810478252146204
# [-16   5]: 303.11419149503627
# [-16   6]: 3.017315407991091
# [-16   7]: -3.7453316884587182
# [-16   8]: 0.7058857707496964
# [-16   9]: 0.9414186046029744
# [-16  10]: 0.8141157492383811
# [-16  11]: 0.7913690696030196
# [-16  12]: 0.7916968956283515
# [-16  13]: 0.7867817502611791
# [-16  14]: 0.7776050151840315
# [-15   1]: -2594880326797.0977
# [-15   2]: -34950.53207883801
# [-15   3]: -752.8945878717583
# [-15   4]: 285.6543228169948
# [-15   5]: 9.410494922661384
# [-15   6]: -3.4824152681007927
# [-15   7]: 0.600244106570886
# [-15   8]: 0.9198624955771743
# [-15   9]: 0.8034528108031518
# [-15  10]: 0.7789645047521856
# [-15  11]: 0.7787523274715477
# [-15  12]: 0.7740165427232752
# [-15  13]: 0.7650877384076934
# [-14   1]: -57716531696.89144
# [-14   2]: -1469.1311724580307
# [-14   3]: 253.8322295945606
# [-14   4]: 15.049101978838644
# [-14   5]: -3.095532624492461
# [-14   6]: 0.5058167122637691
# [-14   7]: 0.8969202052093186
# [-14   8]: 0.7926552416712233
# [-14   9]: 0.7667530013911543
# [-14  10]: 0.7659913448589477
# [-14  11]: 0.7614158455540165
# [-14  12]: 0.7527288102777135
# [-13   1]: -1282698908.5756335
# [-13   2]: 208.41306139938234
# [-13   3]: 19.663609282332942
# [-13   4]: -2.6093411398104096
# [-13   5]: 0.424655976756772
# [-13   6]: 0.8729301761497253
# [-13   7]: 0.7817038258914154
# [-13   8]: 0.7547236013405472

# %% [markdown]
# **********************************************************************************

# %%
# Parameters
r = 0.1
T = 1.0
rho = 0.5
a_plus = 20.4499
a_minus = 24.4499
alpha = 0.4
lambda_ = 10

K = np.linspace(2.0, 4.0, 11)

## Test VG
S0 = np.array([100, 96])
u_bar = 40
N = 128
eta = u_bar * 2 / N
ep = np.array([-5.2, 2.1])

s_res = []
for k in K:
    s = SpreadOption(S0, k, T, r).price(N, eta, ep, "ExpLevy", lambda_, a_plus, a_minus, alpha, T)
    s_res.append(s)
pd.DataFrame({"K": K, "Price": s_res})
# Out:
#       K     Price
# 0   2.0  9.491180
# 1   2.2  9.385025
# 2   2.4  9.279715
# 3   2.6  9.175248
# 4   2.8  9.071624
# 5   3.0  8.968841
# 6   3.2  8.866898
# 7   3.4  8.765794
# 8   3.6  8.665528
# 9   3.8  8.566097
# 10  4.0  8.467500
