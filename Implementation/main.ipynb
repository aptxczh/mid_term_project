# %% [markdown]
# # MTH 9871 Mid-term Project

# %%
"""
Main test file. Generate the result of our code.

Created: 11/27/17

Author: Bingcheng Wang, Yawei Wang & Zhihao Chen
"""
from spread_options import SpreadOption
import numpy as np

# %%
## Parameters
r = 0.1
T = 1.0
rho = 0.5
delta_1 = 0.05
sigma_1 = 0.2
delta_2 = 0.05
sigma_2 = 0.1

# %%
S0 = np.array([100, 96])
N = 128
u_bar = 40
eta = u_bar * 2 / N
ep = np.array([-5.2, 2.1])
s = SpreadOption(S0, 1, T, r).price(N, eta, ep, "GBM", sigma=np.array([sigma_1, sigma_2]), r=r, T=T, rho=rho)

print(s)

# %%
np.exp(np.pi/10)

# %%
print(s)

# %%
S0 = np.array([10, 5])
N = 128
u_bar = 40
eta = u_bar * 2 / N
ep = np.array([-5.2, 2.1])
print(SpreadOption(S0, 1, T, r).P(1000, eta, ep))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-65f6a3e87da1> in <module>()
#       4 eta = u_bar * 2 / N
#       5 ep = np.array([-5.2, 2.1])
# ----> 6 print(SpreadOption(S0, 1, T, r).P(1000, eta, ep))
#
# /Users/hlzswbc/Documents/My Course/Baruch/2017Fall/9871_CM/mid_term_project/Implementation/spread_options.py in P(self, N, eta, ep)
#      83
#      84     def P(self, N, eta, ep):
# ---> 85         return self.__payoff(N, eta, ep, lambda u: 1)
#
# /Users/hlzswbc/Documents/My Course/Baruch/2017Fall/9871_CM/mid_term_project/Implementation/spread_options.py in __payoff(self, N, eta, ep, phi)
#      55
#      56     def __payoff(self, N, eta, ep, phi):
# ---> 57         return 1 / (4 * np.pi**2) * self.__double_int(N, eta, ep, phi)
#      58
#      59     def __double_int(self, N, eta, ep, phi):
#
# /Users/hlzswbc/Documents/My Course/Baruch/2017Fall/9871_CM/mid_term_project/Implementation/spread_options.py in __double_int(self, N, eta, ep, phi)
#      76                 #    print(phi(u))
#      77                 #    print(P_hat(u))
# ---> 78                 H_mat[k1, k2] = -1**(k1+k2) * phi(u) * P_hat(u)
#      79
#      80         res = (-1)**(l[0]+l[1]) * (eta * N)**2 * np.exp(-ep.dot(self.X0)) * ifft2(H_mat)[l[0], l[1]]
#
# TypeError: float() argument must be a string or a number, not 'mpc'
