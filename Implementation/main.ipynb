# %% [markdown]
# # MTH 9871 Mid-term Project

# %%
"""
Main test file. Generate the result of our code.

Created: 11/27/17

Author: Bingcheng Wang, Yawei Wang & Zhihao Chen
"""
from spread_options import SpreadOption
import numpy as np
import pandas as pd

# %%
## Parameters
r = 0.1
T = 1.0
rho = 0.5
delta_1 = 0.05
sigma_1 = 0.2
delta_2 = 0.05
sigma_2 = 0.1
K = 3

## Test Theorem 1.1

S0 = np.array([10, 5])
N = 1000
eta = 0.1
ep = np.array([-2.1, 0.1])

payoff = SpreadOption(S0, K, T, r).P(N, eta, ep)

print("Exact payoff for spread option: {}".format(max((S0[0] - S0[1] - K), 0)))
print("Calculated payoff for spread option: {}".format(payoff))
# Out:
# 2
# 1.96223632525

# %% [markdown]
# **********************************************************************************

# %%
## Parameters
r = 0.1
T = 1.0
rho = 0.5
delta_1 = 0.05
sigma_1 = 0.2
delta_2 = 0.05
sigma_2 = 0.1

K = np.linspace(0.4, 4, 10)

## Test GBM

S0 = np.array([100, 96])
u_bar = 40
eta = u_bar * 2 / N
ep = np.array([-5.8, 2.8])

s_res1, s_res2, s_res3, s_res4 = [], [], [], []
for k in K:
    s1 = SpreadOption(S0, k, T, r).price(64, eta, ep, "GBM", sigma=np.array([sigma_1, sigma_2]), r=r, T=T, rho=rho)
    s_res1.append(s1)
    s2 = SpreadOption(S0, k, T, r).price(128, eta, ep, "GBM", sigma=np.array([sigma_1, sigma_2]), r=r, T=T, rho=rho)
    s_res2.append(s2)
    s3 = SpreadOption(S0, k, T, r).price(256, eta, ep, "GBM", sigma=np.array([sigma_1, sigma_2]), r=r, T=T, rho=rho)
    s_res3.append(s3)
    s4 = SpreadOption(S0, k, T, r).price(32, eta, ep, "GBM", sigma=np.array([sigma_1, sigma_2]), r=r, T=T, rho=rho)
    s_res4.append(s4)

bm = np.array([8.312461, 8.114994, 7.92082, 7.729932, 7.542324, 7.357984, 7.176902, 6.999065, 6.824458, 6.653065])
res = pd.DataFrame({"Benchmark": bm, "K": K, "64": s_res1, "128": s_res2, "256": s_res3, "32": s_res4})[["Benchmark","K", "32", "64", "128", "256"]]
res
# Out:
#    Benchmark    K        32         64       128       256
# 0   8.312461  0.4  8.699968  10.913765  8.331022  8.330968
# 1   8.114994  0.8  8.691133  10.714267  8.117654  8.117817
# 2   7.920820  1.2  8.769636  10.436562  7.908524  7.908768
# 3   7.729932  1.6  8.705161  10.142277  7.703504  7.703793
# 4   7.542324  2.0  8.570430   9.846346  7.502543  7.502862
# 5   7.357984  2.4  8.401548   9.553680  7.305605  7.305943
# 6   7.176902  2.8  8.215878   9.266235  7.112652  7.113003
# 7   6.999065  3.2  8.022383   8.984872  6.923648  6.924006
# 8   6.824458  3.6  7.825993   8.709979  6.738555  6.738916
# 9   6.653065  4.0  7.629560   8.441718  6.557336  6.557695

# %%
N = 256
ep = np.array([-5.8, 2.8])
s = SpreadOption(S0, 0.8, T, r).price(N, eta, ep, "GBM", sigma=np.array([sigma_1, sigma_2]), r=r, T=T, rho=rho)
s
# Out:
# 8.1178165468465977

# %% [markdown]
# **********************************************************************************

# %%
## Parameters
r = 0.1
T = 1.0
rho = 0.5
delta_1 = 0.05
sigma_1 = 1.0
rho_1 = -0.5
delta_2 = 0.05
sigma_2 = 0.5
rho_2 = 0.25
v0 = 0.04
kappa = 1.0
mu = 0.04
sigma_v = 0.05

K = np.linspace(2.0, 4.0, 11)

## Test SV
S0 = np.array([100, 96])
u_bar = 40
eta = u_bar * 2 / N
ep = np.array([-10, 2.35])

s_res1, s_res2, s_res3, s_res4 = [], [], [], []
for k in K:
    s1 = SpreadOption(S0, k, T, r).price(64, eta, ep, "SV", np.array([sigma_1, sigma_2, sigma_v]), r, T, 
                                        np.array([rho, rho_1, rho_2]), kappa, mu, v0, np.array([delta_1, delta_2]))
    s_res1.append(s1)
    s2 = SpreadOption(S0, k, T, r).price(128, eta, ep, "SV", np.array([sigma_1, sigma_2, sigma_v]), r, T, 
                                        np.array([rho, rho_1, rho_2]), kappa, mu, v0, np.array([delta_1, delta_2]))
    s_res2.append(s2)
    s3 = SpreadOption(S0, k, T, r).price(256, eta, ep, "SV", np.array([sigma_1, sigma_2, sigma_v]), r, T, 
                                        np.array([rho, rho_1, rho_2]), kappa, mu, v0, np.array([delta_1, delta_2]))
    s_res3.append(s3)
    s4 = SpreadOption(S0, k, T, r).price(32, eta, ep, "SV", np.array([sigma_1, sigma_2, sigma_v]), r, T, 
                                        np.array([rho, rho_1, rho_2]), kappa, mu, v0, np.array([delta_1, delta_2]))
    s_res4.append(s4)

bm = np.array([7.548502, 7.453536, 7.359381, 7.266037, 7.173501, 7.081775, 6.990857, 6.900745, 6.81144, 6.722939, 6.635242])
res = pd.DataFrame({"Benchmark": bm, "K": K, "64": s_res1, "128": s_res2, "256": s_res3, "32": s_res4})[["Benchmark","K", "32", "64", "128", "256"]]
res
# Out:
#     Benchmark    K            32           64          128          256
# 0    7.548502  2.0  17380.890061  7807.711195  -875.461051 -2118.594120
# 1    7.453536  2.2  10622.243828  -480.498921 -1328.464970  1493.501515
# 2    7.359381  2.4   7774.815523 -1016.941128  1025.465750  1025.047562
# 3    7.266037  2.6   5684.712802   614.433433  -537.577299   551.865622
# 4    7.173501  2.8   3990.768962   526.880470   263.962132   298.301183
# 5    7.081775  3.0   2728.113936    26.947386   -59.276875   101.580211
# 6    6.990857  3.2   1858.921026   -83.601719   -18.942520   -28.032443
# 7    6.900745  3.4   1287.603923    11.435337    72.688477   -18.495334
# 8    6.811440  3.6    917.410887    71.381408   -37.839982    52.122893
# 9    6.722939  3.8    674.692338    60.203447    18.743355    38.725212
# 10   6.635242  4.0    510.712417    27.457415    21.076101    11.844277

# %%
r = 0.1
T = 1.0
rho = 0.5
delta_1 = 0.05
sigma_1 = 1.0
rho_1 = -0.5
delta_2 = 0.05
sigma_2 = 0.5
rho_2 = 0.25
v0 = 0.04
kappa = 1.0
mu = 0.04
sigma_v = 0.05

N = 256

for ep1 in np.arange(-5, 0, 0.3):
    ep2 = -ep1 - 1.5
    
    if ep1 + ep2 >= -1 or ep2 <= 0:
        continue
    ep = np.array([ep1, ep2])
    s = SpreadOption(S0, 2.2, T, r).price(N, eta, ep, "SV", np.array([sigma_1, sigma_2, sigma_v]), r, T, 
                                        np.array([rho, rho_1, rho_2]), kappa, mu, v0, np.array([delta_1, delta_2]))
    print("{}: {}".format(ep, s))
# Out:
# [-5.   3.5]: 12.670254324789337
# [-4.7  3.2]: 12.626733926364198
# [-4.4  2.9]: 12.583433448409531
# [-4.1  2.6]: 12.540351721547658
# [-3.8  2.3]: 12.49748758141864
# [-3.5  2. ]: 12.4548398684609
# [-3.2  1.7]: 12.412407427686064
# [-2.9  1.4]: 12.370189108413767
# [-2.6  1.1]: 12.328183759518316
# [-2.3  0.8]: 12.2863899559266
# [-2.   0.5]: 12.244905491456606
# [-1.7  0.2]: 12.274436243658114

# %% [markdown]
# **********************************************************************************

# %%
# Parameters
r = 0.1
T = 1.0
rho = 0.5
a_plus = 20.4499
a_minus = 24.4499
alpha = 0.4
lambda_ = 10

K = np.linspace(2.0, 4.0, 11)

## Test VG
S0 = np.array([100, 96])
u_bar = 40
eta = u_bar * 2 / N
ep = np.array([-3.1, 1.4])

s_res1, s_res2, s_res3, s_res4 = [], [], [], []
for k in K:
    s1 = SpreadOption(S0, k, T, r).price(64, eta, ep, "ExpLevy", lambda_, a_plus, a_minus, alpha, T)
    s_res1.append(s1)
    s2 = SpreadOption(S0, k, T, r).price(128, eta, ep, "ExpLevy", lambda_, a_plus, a_minus, alpha, T)
    s_res2.append(s2)
    s3 = SpreadOption(S0, k, T, r).price(256, eta, ep, "ExpLevy", lambda_, a_plus, a_minus, alpha, T)
    s_res3.append(s3)
    s4 = SpreadOption(S0, k, T, r).price(32, eta, ep, "ExpLevy", lambda_, a_plus, a_minus, alpha, T)
    s_res4.append(s4)
bm = np.array([9.727458, 9.630006, 9.5332, 9.43704, 9.341528, 9.246662, 9.152445, 9.058875, 8.965954, 8.873681, 8.782057])
res = pd.DataFrame({"Benchmark": bm, "K": K, "64": s_res1, "128": s_res2, "256": s_res3, "32": s_res4})[["Benchmark","K", "32", "64", "128", "256"]]
res
# Out:
#     Benchmark    K        32        64       128       256
# 0    9.727458  2.0  9.453368  8.610473  8.610424  9.745573
# 1    9.630006  2.2  9.330975  8.514269  8.514216  9.646735
# 2    9.533200  2.4  9.209770  8.418830  8.418772  9.548564
# 3    9.437040  2.6  9.089737  8.324156  8.324094  9.451059
# 4    9.341528  2.8  8.970868  8.230245  8.230178  9.354221
# 5    9.246662  3.0  8.853160  8.137096  8.137026  9.258051
# 6    9.152445  3.2  8.736608  8.044709  8.044634  9.162548
# 7    9.058875  3.4  8.621209  7.953082  7.953003  9.067714
# 8    8.965954  3.6  8.506956  7.862214  7.862131  8.973548
# 9    8.873681  3.8  8.393844  7.772104  7.772016  8.880049
# 10   8.782057  4.0  8.281866  7.682749  7.682658  8.787219

# %%
N = 256

for ep1 in np.arange(-4, -3, 0.1):
    for ep2 in np.arange(1, 4, 0.1):
    
        if ep1 + ep2 >= -1 or ep2 <= 0:
            continue
        ep = np.array([ep1, ep2])
        s = SpreadOption(S0, 2.2, T, r).price(N, eta, ep, "ExpLevy", lambda_, a_plus, a_minus, alpha, T)
        print("{}: {}".format(ep, s))
# Out:
# [-4.  1.]: 9.769053992937346
# [-4.   1.1]: 9.757492548013259
# [-4.   1.2]: 9.747676965842475
